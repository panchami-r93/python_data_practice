# %%
import pandas as pd

data = {
    "student": ["A", "B", "C", "D"],
    "math_score": [78, 85, 62, 90],
    "study_hours": [2, 3, 1.5, 4],
}

df = pd.DataFrame(data)
df
# Out:
#   student  math_score  study_hours
# 0       A          78          2.0
# 1       B          85          3.0
# 2       C          62          1.5
# 3       D          90          4.0

# %%
df.describe()
# Out:
#        math_score  study_hours
# count    4.000000     4.000000
# mean    78.750000     2.625000
# std     12.203142     1.108678
# min     62.000000     1.500000
# 25%     74.000000     1.875000
# 50%     81.500000     2.500000
# 75%     86.250000     3.250000
# max     90.000000     4.000000

# %%
import matplotlib.pyplot as plt

plt.scatter(df["study_hours"], df["math_score"])
plt.xlabel("Study hours")
plt.ylabel("Math score")
plt.title("Study hours vs Math score")
plt.show()
